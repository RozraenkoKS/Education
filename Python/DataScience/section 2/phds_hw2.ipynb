# %% [markdown]
# # <a href="https://thetahat.ru/courses/ph-ds-2025-spr">Phystech@DataScience</a>
# ## Домашнее задание 2
#
# **Правила, <font color="red">прочитайте внимательно</font>:**
#
# * Выполненную работу нужно отправить телеграм-боту `@thetahat_ds25_bot`. Для начала работы с ботом каждый раз отправляйте `/start`. Дождитесь подтверждения от бота, что он принял файл. Если подтверждения нет, то что-то не так. **Работы, присланные иным способом, не принимаются.**
# * Дедлайн см. в боте. После дедлайна работы не принимаются кроме случаев наличия уважительной причины.
# * Прислать нужно **ноутбук в формате `ipynb`**. Если вы строите интерактивные графики, их стоит прислать в формате html.
# * Следите за размером файлов. **Бот не может принимать файлы весом более 20 Мб.** Если файл получается больше, заранее разделите его на несколько.
# * Выполнять задание необходимо полностью самостоятельно. **При обнаружении списывания всем участникам списывания дается штраф -2 балла к итоговой оценке за семестр.**
# * Решения, размещенные на каких-либо интернет-ресурсах, не принимаются. Кроме того, публикация решения в открытом доступе может быть приравнена к предоставлении возможности списать.
# * Обратите внимание на <a href="https://thetahat.ru/courses/ai-rules"><b>правила использования ИИ-инструментов</b></a> при решении домашнего задания.
# * **Код из рассказанных на занятиях ноутбуков** можно использовать без ограничений.
# * Для выполнения задания используйте этот ноутбук в качестве основы, ничего не удаляя из него. Можно добавлять необходимое количество ячеек.
# * Комментарии к решению пишите в markdown-ячейках.
# * Выполнение задания (ход решения, выводы и пр.) должно быть осуществлено на русском языке.
# * Решение проверяется системой ИИ-проверки <a href="https://thetahat.ru/"><img src="https://miptstats.github.io/theta_grader_small.png" style="display: inline; vertical-align: middle;"></a> **ThetaGrader**. Результат проверки валидируется и исправляется человеком, после чего комментарии отправляются студентам.
# * Если код будет не понятен проверяющему, оценка может быть снижена.
# * Никакой код из данного задания при проверке запускаться не будет. *Если код студента не выполнен, недописан и т.д., то он не оценивается.*
#
# <b><font size="5" color="red">Важно!!! Правила заполнения ноутбука:</font></b>
# * Запрещается удалять имеющиеся в ноутбуке ячейки, менять местами положения задач.
# * Сохраняйте естественный линейный порядок повествования в ноутбуке сверху-вниз.
# * Отвечайте на вопросы, а также добавляйте новые ячейки в предложенных местах, которые обозначены `<...>`.
# * В markdown-ячейка, содержащих описание задачи, находятся специальные отметки, которые <font color="red"><b>запрещается модифицировать</b></font>.
# * При нарушении данных правил работа может получить 0 баллов.
#
#
# **Перед выполнением задания посмотрите презентацию по выполнению и оформлению домашних заданий с занятия 2.**
#
#
# **Баллы за задание:**
#
# <!-- <b><font color="blue">Легкая часть</font></b> (достаточно на "хор"): -->
# * Задача 1 &mdash; 50 баллов
# * Задача 2 &mdash; 50 баллов
# * Задача 3 &mdash; 30 баллов
#
#
#
#
#
#
#
#
# -----

# %%
# Bot check

# HW_ID: phds_hw2
# Бот проверит этот ID и предупредит, если случайно сдать что-то не то

# Status: final
# Перед отправкой в финальном решении удали "not" в строчке выше
# Так бот проверит, что ты отправляешь финальную версию, а не промежуточную

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler


import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
sns.set_theme(palette='Set2')

# %% [markdown]
# ### <font color="blue">Легкая часть</font>

# %% [markdown]
# ---
# ### Задача 1
#
#
# #### 1. Загрузка данных и предобработка

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- 9c620b5e71dfb8e728703d73d13c9bc3 -->
#
# #### **Профиль биология**
#
# Загрузите [данные](https://www.kaggle.com/datasets/marshuu/breast-cancer) по предсказанию рака груди.

# %%
data = pd.read_csv('breast_cancer_disbalances.csv')
data.head()
# Out:
#    Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 0                5                        1                         1
# 1                5                        4                         4
# 2                3                        1                         1
# 3                6                        8                         8
# 4                4                        1                         1
#
#    Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# 0                  1                            2            1
# 1                  5                            7           10
# 2                  1                            2            2
# 3                  1                            3            4
# 4                  3                            2            1
#
#    Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0                3                1        1      2
# 1                3                2        1      2
# ...

# %% [markdown]
# Проверьте, имеются ли в ваших данных пропуски. Если да, то удалите их.

# %%
data.isna().sum()
# Out:
# Clump Thickness                0
# Uniformity of Cell Size        0
# Uniformity of Cell Shape       0
# Marginal Adhesion              0
# Single Epithelial Cell Size    0
# Bare Nuclei                    0
# Bland Chromatin                0
# Normal Nucleoli                0
# Mitoses                        0
# Class                          0
# dtype: int64

# %% [markdown]
# Библиотека `pandas` позволяет строить графики `matplotlib` для своих объектов `DataFrame` ([подробнее](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)). Посмотрим, как распределены значения признака `Bare Nuclei` для разных классов:

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
data.groupby("Class")['Bare Nuclei'].hist(ax=axs[0], alpha=0.5, legend=True)
data.groupby("Class")['Bare Nuclei'].plot(kind='kde', ax=axs[1], legend=True)
axs[0].set_title('Гистограмма для Bare Nuclei', fontsize=20)
axs[1].set_title('KDE для Bare Nuclei', fontsize=20)
axs[1].axvline(x=1, color ='b', alpha=0.6)

# %% [markdown]
# Чем отличаются способы построения ЯОП и гистограммы? Какую информацию о наших данных можно извлечь из каждого графика?

# %% [markdown]
# **Ответ:** ЯОП строит непрерывную гладкую нормированную кривую. Гистограмма дискретна и не нормируется. Из гистограммы мы видим абсолютное распределение, и можем сравнить два класса. Класс 2 встречается много менее редко, чем класс 4. Также по ней ясно для класса 4, что для Bare Nuclei значение 10 встречается в нескольк раз чаще, порядка 5000, чем все остальные значения. Однако она совсем не информативна по классу 2. Из ЯОП видно, что значение Bare Nuclei равное 1 для класса 2 много больше всех остальных, порядка 500. Также на ЯОП можно сравнить относительные количественные распрделения.

# %% [markdown]
# Постройте гистограммы и ядерные оценки плотности для всех признаков из датасета отдельно для каждого класса. `Class` — целевая переменная. Можно это сделать, опираясь на код выше, а можно воспользоваться параметром `hue` у функции [`sns.histplot`](https://seaborn.pydata.org/generated/seaborn.histplot.html) или другим методом, который вам нравится. Не забывайте подписывать, к чему относится каждый график.

# %%
feature_columns = data.columns.values[:-1]
fig, axs = plt.subplots(9, 2, figsize=(10, 30))
for i in range(9):
    data.groupby('Class')[feature_columns[i]].hist(ax=axs[i][0], alpha = 0.6, legend=True)
    data.groupby('Class')[feature_columns[i]].plot(kind='kde', ax=axs[i][1], legend=True)
    axs[i][0].set_title(f'Гистограмма для {feature_columns[i]}')
    axs[i][0].set_xticks(range(0, 11))
    axs[i][1].set_title(f'KDE для {feature_columns[i]}')
    axs[i][1].set_xticks(range(-2, 13))
plt.tight_layout()
plt.show()

# %% [markdown]
# Какие выводы вы можете сделать из полученных графиков?

# %% [markdown]
# # Выводы по распределениям признаков
#
# ---
#
# ### Clump Thickness
# - **Класс 4:**
#   - Признаков класса 4 значительно больше, чем класса 2.
#   - Основные пики приходятся на значения:
#     - 5 и 8 (≈2000)
#     - 10 (≈3000)
#   - Остальные значения распределены более равномерно (≈1000).
#   - Минимальные значения при 1 и 2 (<500).
#
# - **Класс 2:**
#   - Пики наблюдаются при значениях 1, 3, 5 (<500).
#   - Остальные значения (вне диапазона 1–5) значительно ниже.
#
# ---
#
# ### Uniformity of Cell Size
# - **Класс 4:**
#   - Признаков класса 4 больше, чем класса 2.
#   - Пик приходится на значение 10 (>2500).
#   - Минимумы – при значениях 1, 2 и 9 (<500).
#   - Остальные значения распределены равномерно (≈1000).
#
# - **Класс 2:**
#   - Пик, даже превосходящий класс 4, приходится на значение 1 (<500).
#   - Остальные значения почти равны нулю (с небольшими пиками для 2 и 3).
#
# ---
#
# ### Uniformity of Cell Shape
# - **Аналогично распределению для Uniformity of Cell Size.**
#
# ---
#
# ### Marginal Adhesion
# - **Похоже на Uniformity of Cell Size,**
#   - Однако для класса 4 минимальные значения при 1 и 2 распределены аналогично диапазону 3–8.
#
# ---
#
# ### Single Epithelial Cell Size
# - **Класс 2:**
#   - Пик приходится на значение 2 (>250).
#   - Остальные значения – около нуля (с небольшими пиками для 1 и 3).
#
# - **Класс 4:**
#   - Значения 2 и 8 имеют близкие пики (≈750).
#   - Значение 7 – ниже (<500).
#   - Минимумы наблюдаются при 1 и 9 (около 0).
#   - Значения 3–6 и 10 распределены равномерно (от 1250 до 1750).
#
# ---
#
# ### Bare Nuclei
# - **См. выше.**
#
# ---
#
# ### Bland Chromatin
# - **Класс 4:**
#   - Основной пик приходится на значение 7 (≈2500).
#   - Значения в диапазоне 3–5, 8 и 10 распределены примерно равномерно (≈1000).
#   - Значения 2, 6 и 8 – ниже (≈500 или меньше).
#   - Значение 1 – около нуля.
#
# - **Класс 2:**
#   - Пики приходятся на значения 1, 2 и 3 (<500).
#   - Остальные значения – минимальны (около нуля).
#
# ---
#
# ### Normal Nucleoli
# - **Класс 4:**
#   - Пик приходится на значение 10 (≈2500).
#   - Диапазон 4–9 распределён равномерно (>500).
#   - Небольшие пики наблюдаются при 1 и 3 (≈1500).
#   - Минимум – при значении 2 (<500).
#
# - **Класс 2:**
#   - Распределение аналогично тому, что наблюдается для Uniformity of Cell Size.
#
# ---
#
# ### Mitoses
# - **Класс 4:**
#   - Основной пик приходится на значение 1 (>5000).
#   - Значения 2–3 – ниже (≈1000).
#   - Значения 4, 7, 8 и 10 – ещё ниже (≈500).
#   - Значения 6 и 8 – минимальны (около 0).
#
# ---

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- 00000000000000000000000000000000 -->
# **Это не конец задачи! Переходите к пункту 2!**

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- ca9029c0d916da0e69572b206fa25145 -->
# #### **Профиль физика**
#
# Загрузите данные по бинарной классификации астероидов в зависимости от различных параметров с <a href="https://thetahat.ru/courses/ph-ds-2025-spr">сайта</a>.
#
# Вашей целевой переменной будет являться столбец `pha`. Более подробно ознакомить с датасетом вы можете также [здесь](https://www.kaggle.com/datasets/sakhawat18/asteroid-dataset/data). Можно заметить, что наш датасет сильно меньше по размерам, чем оригинал. Это сделано намеренно.

# %%
data = pd.read_csv('asteroid_cut.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 951 entries, 0 to 950
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pha             951 non-null    object
#  1   diameter        951 non-null    float64
#  2   albedo          951 non-null    float64
#  3   diameter_sigma  951 non-null    float64
#  4   epoch           951 non-null    float64
#  5   epoch_mjd       951 non-null    int64
#  6   epoch_cal       951 non-null    float64
#  7   i               951 non-null    float64
#  8   om              951 non-null    float64
#  9   w               951 non-null    float64
#  10  ma              951 non-null    float64
#  11  ad              951 non-null    float64
#  12  tp              951 non-null    float64
#  13  tp_cal          951 non-null    float64
#  14  sigma_e         951 non-null    float64
#  15  sigma_a         951 non-null    float64
#  16  sigma_q         951 non-null    float64
# ...

# %%
data.head()
# Out:
#   pha  diameter  albedo  diameter_sigma      epoch  epoch_mjd   epoch_cal  \
# 0   Y     0.674   0.246           0.014  2459000.5      59000  20200531.0
# 1   N     3.784   0.039           0.043  2459000.5      59000  20200531.0
# 2   N     8.119   0.035           0.416  2459000.5      59000  20200531.0
# 3   N     1.961   0.264           0.356  2459000.5      59000  20200531.0
# 4   N     6.652   0.048           0.172  2459000.5      59000  20200531.0
#
#            i          om           w  ...       sigma_q   sigma_i  sigma_om  \
# 0  45.866197  150.740973  322.105952  ...  4.207900e-08  0.000016  0.000005
# 1  15.888281  158.041201  111.859817  ...  1.562300e-07  0.000006  0.000024
# 2  15.026047  203.726362  124.436743  ...  1.254500e-07  0.000006  0.000016
# 3   1.851420  133.373581  280.521600  ...  1.048100e-07  0.000004  0.000139
# 4   3.687808   91.553962  305.870014  ...  8.995300e-08  0.000004  0.000065
#
# ...

# %% [markdown]
# Библиотека `pandas` позволяет строить графики `matplotlib` для своих объектов `DataFrame` ([подробнее](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)). Посмотрим, как распределены значения признака `rms` для разных классов:

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
data.groupby("pha")['rms'].hist(ax=axs[0], density=True, legend=True, alpha=0.6)
data.groupby("pha")['rms'].plot(kind='kde', ax=axs[1], legend=True)
axs[0].set_title('Гистограмма для H', fontsize=20)
axs[1].set_title('KDE для H', fontsize=20);

# %% [markdown]
# Чем отличаются способы построения ЯОП и гистограммы? Какую информацию о наших данных можно извлечь из каждого графика?

# %% [markdown]
# **Ответ:**
# Оба распределения схожи нормальному. Медианное значение для `'pha' = N` составляет около 0.53, что немного больше, чем для `'pha' = Y` (≈0.49). При этом стандартное отклонение для Y выше, чем для N (отличие примерно в 1.5 раза, согласно правилу 3σ).
# Так как гистограмма строится с параметром `density=True`, абсолютные значения масштабов не имеют прямого смысла. При этом пик распределения для N примерно в 1.5 раза выше, чем для Y.

# %% [markdown]
# Постройте гистограммы и ядерные оценки плотности для указанных ниже признаков отдельно для каждого класса. `pha` — целевая переменная. Можно это сделать, опираясь на код выше, а можно воспользоваться параметром `hue` у функции [`sns.histplot`](https://seaborn.pydata.org/generated/seaborn.histplot.html) или другим методом, который вам нравится. Не забывайте подписывать, к чему относится каждый график.

# %%
feature_columns = ['epoch', 'ma', 'tp', 'rms']
fig, axs = plt.subplots(4, 2, figsize=(8, 15))
for i in range(4):
    data.groupby('pha')[feature_columns[i]].hist(ax=axs[i][0], alpha = 0.6, legend=True, density=True)
    data.groupby('pha')[feature_columns[i]].plot(kind='kde', ax=axs[i][1], legend=True)
    axs[i][0].set_title(f'Гистограмма для {feature_columns[i]}')
    axs[i][1].set_title(f'KDE для {feature_columns[i]}')
plt.tight_layout()
plt.show()

# %% [markdown]
# Какие выводы вы можете сделать из полученный графиков?

# %% [markdown]
# **Вывод:**
#
# ### Признак epoch
# - Распределения для классов N и Y идентичны и напоминают нормальное распределение с медианой ≈ 2.458.
# - Однако пик распределения для класса N при 2.458 в 1.33 раза выше, чем для класса Y.
# - Кроме того, у класса N наблюдается небольшой дополнительный пик около 2.454 (почти на нуле).
#
# ---
#
# ### Признак ma
# - Распределения для классов N и Y также идентичны и похожи на нормальное распределение с медианой ≈ 200.
# - Отличие в том, что:
#   - Для класса Y пик смещён влево от основной линии.
#   - Для класса N пик смещён вправо от основной линии.
#
# ---
#
# ### Признак tp
# - Распределения для классов N и Y идентичны и напоминают нормальное распределение с медианой ≈ 2.458.
# - При этом пик распределения для класса Y в 1.66 раза выше, чем для класса N.
#
# ---
#
# ### Признак rms
# - **См. выше.**
#
# ---

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- 30a722e795d939966c91ff0a92cf86eb -->
# #### 2. Обучение модели
#
# Продолжайте использовать выбранные вами данные.

# %% [markdown]
# Создайте массив признаков и массив таргета. Разбейте ваши данные на обучающую и тестовую выборки в отношении 7:3.

# %%
X = data.drop('pha', axis=1)
y = data['pha']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)

# %% [markdown]
# Примените стандартизацию к обучающей и тестовой выборкам, используя класс <a href="https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler">`StandardScaler`</a>, натренированный на обучающей выборке.

# %%
scaler = StandardScaler()
scaler.fit_transform(X_train)
scaler.transform(X_test);

# %% [markdown]
# Объясните, что делает `StanderdScaler` и почему нельзя его нельзя обучать на тестовой выборке?

# %% [markdown]
# **Ответ:**
#
# StandardScaler для каждого столбца высчитывает среднее по нему и стандартное отклонени. А затем поэлементно в нём вычитает среднее, а результат делит на стандартное отклонени. На тестовой выборке нельзя обучаться, потому что мы хотим проверить, как хорошо обучена модель на наших данных, то есть модель не должны заранее знать данные

# %% [markdown]
# Обучите модель логистической регрессии.

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Сделайте предсказание для тестовой выборки и оцените качества полученного предсказания, используя метрику `accuracy_score`
#
# Если названия ваших классов отличаются от 0 и 1, то надо использовать `pos_label`.

# %%
y_pred = model.predict(X_test)
accuracy_score(y_test, y_pred)
#Аргумент pos_label отсутствует
# Out:
# 0.8146853146853147

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- 720b0d3dae956d90fb3ea500b9479d13 -->
# Можем ли порадоваться таким результатам? Вернемся к гистограммам и сделаем вывод, почему метрика оказалась такой большой.
#
# Давайте посмотрим на распределение наших данных по целевой переменной по всему датасету, тренировочной и тестовой выборках.

# %%
original = data['pha'].value_counts() # Колонка таргета из изначального датасета
train = y_train.value_counts() # Колонка таргета из тренировочного датасета
test = y_test.value_counts() # Колонка таргета из тестового датасета

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
sns.barplot(x=original.index, y=original, ax=axes[0], palette=['blue'])
axes[0].set_title('Распределение классов в data')
axes[0].set_ylabel('Количество')
axes

sns.barplot(x=train.index, y=train, ax=axes[1], palette=['green'])
axes[1].set_title('Распределение классов в train')

sns.barplot(x=test.index, y=test, ax=axes[2], palette=['orange'])
axes[2].set_title('Распределение классов в test')

plt.show()

# %% [markdown]
# Видно, что в данных есть сильный перекос — классы представлены неравномерно. Как и почему это может повлиять на наши результаты?

# %% [markdown]
# **Ответ:** Модель подстроит свои параметры для какой-то части выборки из тренировочных давнных. Так как данные неравномерны, то эти параметры не будут подходить для тестовых давнных

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- 27d23fce3fb2cb6960814deb0a13d80b -->
# Есть много способов борьбы с этим. Можно искусственно сгенерировать данные нужного класса или урезать другой класс. Однако сегодня мы воспользуемся ***взвешенной*** логистической регрессией. Суть метода в том, что мы вручную поставим веса для классов, исходя из их предполагаемой природы: важность разных классов, цена ошибки в реальной жизни(например, что лучше, предсказать наличие рака, если он есть или нет?) и представленность данных.
#
# Кросс-энтропия для взвешенной логистической регресси будет записана как:
#
# $$
# F(\theta) = \sum_{i=1}^{n} H(y_i, \widehat{y}_i) = -\sum_{i=1}^{n} w_{y_i} \left[ y_i \log(\widehat{y}_i) + (1-y_i) \log(1-\widehat{y}_i) \right]
# $$
#
# где:
#
# - $ y_i $ - истинный класс для образца  $i$
# - $ \widehat{y}_i = \sigma(\theta^Tx_i)$ - предсказанный класс для образца $i$
# - $ w_{y_i} $ - вес класса
#
#
#
# Давайте применим этот подход на практике. Воспользуемся параметром `class_weight`. Для начала определим количество примеров каждого класса в обучающей выборке и вычислим их соотношение.

# %%
print(y_train.value_counts())
# Out:
# pha
# N    537
# Y    128
# Name: count, dtype: int64

# %% [markdown]
# Применим рассчитанное соотношение классов в качестве весов:

# %%
threshold = 126 / (126 + 539)
class_weights = {'Y': threshold, 'N': 1 - threshold}
# если использовать class_weights = 'balanced' модель сама подсчитает веса

weighted_model = LogisticRegression(class_weight=class_weights, random_state=0)
weighted_model.fit(X_train, y_train)
y_pred = weighted_model.predict(X_test)

# %% [markdown]
# Посчитаем метрику `accuracy_score`:

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"accuracy = {accuracy}")
# Out:
# accuracy = 0.8146853146853147

# %% [markdown]
# Как изменилось качество нашей модели?
#
# Сделайте общий вывод по задаче.

# %% [markdown]
# **Вывод:** Не изменилось)). В целом пользоваться class_weights имеет в случае, если нужно учитывать важных разных классов

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- d47d648e3e531cd82a72ebefc5133104 -->
# ---
# ### Задача 2
#
#
# #### Датасет penguins
# В первой части задания мы познакомимся с новым для нас датасетом

# %%
penguins = pd.read_csv('penguins.csv')
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen            36.7           19.3              193.0
# 4  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    male
# 1       3800.0  female
# 2       3250.0  female
# 3       3450.0  female
# 4       3650.0    male

# %% [markdown]
# > ⚠️ **Warning:** Лучше не нажимать на пингвинов

# %% [markdown]
# Здесь содержатся данные о морфололгии пингвинов трех различных видов: Adelie, Chinstrap, и Gentoo.

# %% [markdown]
# <img width="450" src="data:image/jpeg;base64,..."/>

# %% [markdown]
# Оставшеися колонки: `bill_length_mm`, `bill_depth_mm`, `flipper_length_mm`, `body_mass_g` описывают морфологию каждого пингвина.

# %% [markdown]
# <img width="350" src="data:image/jpeg;base64,..."/>

# %% [markdown]
# Как мы видим, в данном датасете присутствуют категориальные переменные: `species`, `island` и `sex`, которые не могут быть оценены моделью линейной регресии. Закодируйте их: к переменным, где присутствует более трёх категорий, примените преобразование `OneHotEncoder`. Обратите внимание на аргумент [`drop`](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html).

# %%
print(penguins['island'].unique(), '\n', penguins['species'].unique())
# Out:
# ['Torgersen' 'Biscoe' 'Dream']
#  ['Adelie' 'Gentoo' 'Chinstrap']

# %%
cat_features = ['species', 'island', 'sex']

onehotencoder = OneHotEncoder(sparse_output=False, drop='first')
encoded = pd.DataFrame(onehotencoder.fit_transform(penguins[cat_features]), dtype=int)

penguins_encoded = penguins.drop(cat_features, axis=1).join(encoded)
penguins_encoded = penguins_encoded.rename(str, axis="columns")

penguins_encoded.head()
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  0  1  2  3  \
# 0            39.1           18.7              181.0       3750.0  0  0  0  1
# 1            39.5           17.4              186.0       3800.0  0  0  0  1
# 2            40.3           18.0              195.0       3250.0  0  0  0  1
# 3            36.7           19.3              193.0       3450.0  0  0  0  1
# 4            39.3           20.6              190.0       3650.0  0  0  0  1
#
#    4
# 0  1
# 1  0
# 2  0
# 3  0
# 4  1

# %% [markdown]
# Выберем в качестве таргета вес пингвинов (`body_mass_g`), и разделим нашу выборку на тренировочную и тестовую:

# %%
X = penguins_encoded.drop('body_mass_g', axis=1)
y = penguins_encoded['body_mass_g']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- 609f7e6bc983c66d5814592a5352a7e0 -->
# Реализуйте линейную регрессию самостоятельно, используя формулы с лекции.
# Вам нужно только заполнить прочерки в методах `fit` и `predict`.

# %%
class MyLinearRegression:
    """
    Класс, реализующий линейную регрессию c помощью МНК.
    """

    def __init__(self):
        pass

    def fit(self, X, Y):
        """
        Функция обучения модели.

        Предполагается модель Y = X * theta + epsilon.
        где X --- регрессор (матрица размера n x d),
        Y --- отклик (матрица размера n x 1),
        epsilon-ы имеют нормальное распределение

        Обратите внимание, здесь нет intercept_
        """
        
        self.n, self.d = X.shape[0], X.shape[1]
        
        self.theta = np.dot(np.linalg.pinv(X), Y)

        return self


    def predict(self, X):
        """
        Возвращает предсказание отклика на новых объектах X.

        X --- матрица объектов размера n x d
        """

        y_pred =  np.dot(X, self.theta)
        return y_pred

# %% [markdown]
# Обучите вашу модель на датасете о пингвинах **без** добавления свободного члена.
# Распечатайте коэффициенты и сравните их с коэффициентами модели из `sklearn`.

# %%
MyModel = MyLinearRegression()
MyModel.fit(X_train, y_train)
y_pred1 = MyModel.predict(X_test)

# %%
model = LinearRegression(fit_intercept=False)
model.fit(X_train, y_train)
y_pred2 = model.predict(X_test)

# %%
print(y_pred1, y_pred2)
# Out:
# [3272.50489733 3690.92901784 3294.63984151 5320.89789518 4598.51148797
#  4151.49459206 3450.60979275 3913.58622418 4646.05677507 3455.03317259
#  3990.66899089 5421.55149588 3473.03932306 3333.43227166 3433.49095849
#  4659.96891623 5260.72323809 5431.62063677 4646.59355618 3317.63216545
#  4934.54235541 4675.31962521 5388.85609354 5638.76283749 4207.62017356
#  3768.97566385 3289.89536878 3468.93582819 4927.7672915  4904.02851868
#  5283.60899455 4140.64381847 4721.03553884 3282.67389993 4196.78362
#  3432.41461651 4628.66331135 3432.98031307 5250.39611787 4934.92367551
#  5418.1771996  4657.34777459 3199.45671152 4698.42175522 3911.72089382
#  4058.82591307 3923.39321344 4860.78545027 5517.72545351 3852.5686862
#  3381.91291026 3509.97085966 3946.86705485 3494.74183441 3434.48384259
#  3463.56287683 4800.90207277 3253.5685175  3620.41897178 3435.50923458
#  3554.35762387 3507.59222725 3596.29144978 3393.42028332 4295.79687299
# ...

# %% [markdown]
# Как соотносятся коэффициенты вашей модели и реализации из `sklearn`?
#
# **Ответ:** Полностью совпадают, что говорит об эквивалентной реализации

# %% [markdown]
# Теперь обучите собственную модель **c** добавлением свободного члена.

# %%
X_train_1, X_test_1 = np.hstack((X_train, np.ones((X_train.shape[0], 1)))), np.hstack((X_test, np.ones((X_test.shape[0], 1))))

# %%
MyModel = MyLinearRegression()
MyModel.fit(X_train_1, y_train)
y_pred3 = MyModel.predict(X_test_1)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred4 = model.predict(X_test)

# %%
print(y_pred3, y_pred4)
# Out:
# [3272.50489733 3690.92901784 3294.63984151 5320.89789518 4598.51148797
#  4151.49459206 3450.60979275 3913.58622418 4646.05677507 3455.03317259
#  3990.66899089 5421.55149588 3473.03932306 3333.43227166 3433.49095849
#  4659.96891623 5260.72323809 5431.62063677 4646.59355618 3317.63216545
#  4934.54235541 4675.31962521 5388.85609354 5638.76283749 4207.62017356
#  3768.97566385 3289.89536878 3468.93582819 4927.7672915  4904.02851868
#  5283.60899455 4140.64381847 4721.03553884 3282.67389993 4196.78362
#  3432.41461651 4628.66331135 3432.98031307 5250.39611787 4934.92367551
#  5418.1771996  4657.34777459 3199.45671152 4698.42175522 3911.72089382
#  4058.82591307 3923.39321344 4860.78545027 5517.72545351 3852.5686862
#  3381.91291026 3509.97085966 3946.86705485 3494.74183441 3434.48384259
#  3463.56287683 4800.90207277 3253.5685175  3620.41897178 3435.50923458
#  3554.35762387 3507.59222725 3596.29144978 3393.42028332 4295.79687299
# ...

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- cf209df06ad3ab80411542037954e29d -->
# Помимо рассмотренных на семенаре метрик, довольно часто рассматривают [коэфициент детерминации](https://en.wikipedia.org/wiki/Coefficient_of_determination) $R^2$, который может быть более интуитивным.

# %% [markdown]
# Определяется он так:
# $$
#     R^2 = 1 - \frac{SS_{reg}}{SS_{tot}},
# $$
# где $SS_{res} = \sum\limits_{i=1}^n (y_i - f_i)^2$ отражает точность нашей модели,
# a $SS_{tot} = \sum\limits_{i=1}^n (y_i - \overline{y})^2$ отражает дисперсию исходных данных.
# Соответсвенно чем результат ближе к еденице тем более точная у нас модель и тем лучше она предсказывает. Отрицательный же результат можем получить в случае, если наша модель предсказывает хуже, чем предсказание средним.

# %% [markdown]
# В `sklearn` есть готовая [реализация](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html) под названием `r2_score`

# %% [markdown]
# Сравните качество моделей со свободным членом и без него на тестовой выборке, используя метрики RMSE, MAE, MAPE и $R^2$.

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

metrics = [rmse, mean_absolute_error, mean_absolute_percentage_error, r2_score]
metric_names = ['root_mean_squared_error', 'mean_absolute_error', 'mean_absolute_percentage_error', 'r2_score']

print('Значения без учёта сдвига:')
for name, func in zip(metric_names, metrics):
    print(f'По метрике {name}: {func(y_test, y_pred2)}')
# Out:
# Значения без учёта сдвига:
# По метрике root_mean_squared_error: 307.9963522083349
# По метрике mean_absolute_error: 236.0704687417079
# По метрике mean_absolute_percentage_error: 0.055870973153813425
# По метрике r2_score: 0.8722932099992856

# %%
print('Значения с учётом сдвига:')
for name, func in zip(metric_names, metrics):
    print(f'По метрике {name}: {func(y_test, y_pred4)}')
# Out:
# Значения с учётом сдвига:
# По метрике root_mean_squared_error: 307.9963522083356
# По метрике mean_absolute_error: 236.07046874170754
# По метрике mean_absolute_percentage_error: 0.05587097315381323
# По метрике r2_score: 0.872293209999285

# %% [markdown]
# **Сделайте выводы**

# %% [markdown]
# **Вывод:** Со сдвигом и без сдвига получаются примерно равные результаты

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- 00000000000000000000000000000000 -->
# ---
# ### Задача 3
#
# Во взвешенном методе наименьших квадратов каждому наблюдению задается некоторый известный вес $w_i$. Задача имеет вид: $$\sum\limits_{i=1}^n w_i\left(Y_i - x_i^T \theta\right)^2 \to \min\limits_\theta$$ Найдите решение задачи в матричном виде.

# %% [markdown]
# # Задача 3
#
# **Во взвешенном методе наименьших квадратов** каждому наблюдению задается известный вес \(w_i\). Задача имеет вид:
#
# $$
# \min_{\theta} \sum_{i=1}^n w_i \bigl(Y_i - x_i^T \theta \bigr)^2.
# $$
#
# Пусть:
# - \(X\) — матрица признаков (размер \(n \times p\), где \(n\) — число наблюдений, \(p\) — число признаков);
# - \(Y\) — вектор ответов (размер \(n \times 1\));
# - \(W\) — диагональная матрица весов (размер \(n \times n\)), где \(W_{ii} = w_i\).
#
# Тогда задача минимизации в матричной форме записывается как:
#
# $$
# \min_{\theta} \;\; (Y - X\theta)^T \, W \, (Y - X\theta).
# $$
#
# Чтобы найти оптимальный вектор параметров \(\theta\), вычислим градиент по \(\theta\) и приравняем его к нулю:
#
# $$
# \nabla_\theta \Bigl[(Y - X\theta)^T W (Y - X\theta)\Bigr]
# = -2\,X^T W\,(Y - X\theta) = 0.
# $$
#
# Из этого следует нормальное уравнение:
#
# $$
# X^T W X \,\theta = X^T W \, Y.
# $$
#
# При условии, что матрица \(X^T W X\) обратима, решение имеет вид:
#
# $$
# \theta = \bigl(X^T W X\bigr)^{-1} \, X^T W \, Y.
# $$
