# %%
import json
import pandas as pd

# %%
with open('abstracts.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

df = pd.DataFrame(list(data.items()), columns=['idx', 'abstract'])

# %%
df.head()
# Out:
#   idx                                           abstract
# 0   0  The rapid proliferation of large language mode...
# 1   1  This work introduces a federated learning (FL)...
# 2   2  The ability of visual systems to bind features...
# 3   3  Graph Neural Networks (GNNs) have achieved rem...
# 4   4  Large Language Model (LLM)-based autonomous ag...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4050 entries, 0 to 4049
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   idx       4050 non-null   object
#  1   abstract  4050 non-null   object
# dtypes: object(2)
# memory usage: 63.4+ KB

# %%
df.iloc[0, :]['abstract']
# Out:
# 'The rapid proliferation of large language models (LLMs) has spurred interest in their deployment for legal reasoning, yet empirical evidence on their reliability remains sparse for low‑resource languages. This study presents the first systematic assessment of LLMs on Bengali legal texts, juxtaposing their judgments with those of seasoned legal professionals. We curated a balanced corpus of 1,200 Bengali court decisions spanning criminal, civil, and constitutional domains, annotated by a panel of five qualified Bengali lawyers for factual correctness, legal reasoning, and compliance with procedural norms. Four state‑of‑the‑art LLMs (ChatGPT‑4, BanglaGPT, Open‑AI’s fine‑tuned LLM, and a local transformer trained on Bengali corpora) were prompted using the “LLM‑as‑Judge” paradigm, which elicits case‑specific verdicts, reasoning, and citation references. Performance was evaluated on three metrics: (i) factual accuracy (percentage of correct factual assertions), (ii) legal consistency (a
# ...
