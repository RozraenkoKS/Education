# %% [markdown]
# # Машинное обучение, DS-поток
# ## Задание ML.2
#
#
# **Правила:**
#
# * Дедлайны см. в боте. После дедлайна работы не принимаются кроме случаев наличия уважительной причины.
# * Прислать нужно **ноутбук в формате `ipynb`**.
# * Следите за размером файлов. **Бот не может принимать файлы весом более 20 Мб.** Если файл получается больше, заранее разделите его на несколько.
# * Выполнять задание необходимо полностью самостоятельно. **При обнаружении списывания все участники списывания будут сдавать устный зачет.**
# * Решения, размещенные на каких-либо интернет-ресурсах, не принимаются. Кроме того, публикация решения в открытом доступе может быть приравнена к предоставлении возможности списать.
# * Для выполнения задания используйте этот ноутбук в качестве основы, ничего не удаляя из него. Можно добавлять необходимое количество ячеек.
# * Комментарии к решению пишите в markdown-ячейках.
# * Выполнение задания (ход решения, выводы и пр.) должно быть осуществлено на русском языке.
# * Решение проверяется системой ИИ-проверки <a href="https://thetahat.ru/"><img src="https://miptstats.github.io/theta_grader_small.png" style="display: inline; vertical-align: middle;"></a> **ThetaGrader**. Результат проверки валидируется и исправляется человеком, после чего комментарии отправляются студентам.
# * Если код будет не понятен проверяющему, оценка может быть снижена.
# * Никакой код из данного задания при проверке запускаться не будет. *Если код студента не выполнен, недописан и т.д., то он не оценивается.*
# * В каждой задаче не забывайте делать **пояснения и выводы**.
#
#
# **Правила оформления теоретических задач:**
#
# * Решения необходимо прислать одним из следующих способов:
#   * фотографией в правильной ориентации, где все четко видно, а почерк разборчив,
#     * отправив ее как файл боту вместе с ноутбуком *или*
#     * вставив ее в ноутбук посредством `Edit -> Insert Image` (<font color="red">фото, вставленные ссылкой, не принимаются</font>);
#   * в виде $LaTeX$ в markdown-ячейках.
# * Решения не проверяются, если какое-то требование не выполнено. Особенно внимательно все проверьте в случае выбора второго пункта (вставки фото в ноутбук). <font color="red"><b>Неправильно вставленные фотографии могут не передаться при отправке.</b></font> Для проверки попробуйте переместить `ipynb` в другую папку и открыть его там.
# * В решениях поясняйте, чем вы пользуетесь, хотя бы кратко. Например, если пользуетесь независимостью, то достаточно подписи вида "*X и Y незав.*"
# * Решение, в котором есть только ответ, и отсутствуют вычисления, оценивается в 0 баллов.
#
# **Баллы за задание**
#
# * Задача 1 &mdash; 20 баллов;
# * Задача 2 &mdash; 20 баллов;
# * Задача 3 &mdash; 40 баллов;
# * Задача 4 &mdash; 120 баллов;
# * Задача 5 &mdash; уточняется.

# %%
# Bot check

# HW_ID: ds_ml2
# Бот проверит этот ID и предупредит, если случайно сдать что-то не то.

# Status: not final
# Перед отправкой в финальном решении удали "not" в строчке выше.
# Так бот проверит, что ты отправляешь финальную версию, а не промежуточную.
# Никакие значения в этой ячейке не влияют на факт сдачи работы.

# %%
import numpy as np
import pandas as pd

from sklearn.base import BaseEstimator
from sklearn.metrics import accuracy_score, r2_score
from sklearn.model_selection import train_test_split
from typing import Optional, Callable

import matplotlib.pyplot as plt
import seaborn as sns

sns.set(font_scale=1.3, palette="Set2")

# %% [markdown]
# ### Задача 1

# %% [markdown]
# Докажите, что индекс Джини равен вероятности ошибки случайного классификатора, который выдаёт предсказания с вероятностями пропорционально доле классов в выборке.

# %% [markdown]
# см. влож.

# %% [markdown]
# ### Задача 2

# %% [markdown]
# Пусть $X = (x_1, ..., x_n)$ &mdash; выборка объектов и $Y = (Y_1, ..., Y_n)$ &mdash; соответствующие значения вещественного таргета. Мера неоднородности для набора объектов вычисляется на основе того, насколько хорошо их таргет предсказывается константой:
#
# $$
# H(X) = \min_{c \in \mathscr{Y}} \dfrac{1}{n} \sum_{i=1}^n L(Y_i, c),
# $$
#
# где $L(y, c)$ &mdash; некоторая функция потерь, $\mathscr{Y}$ &mdash; множество значений таргета. Соответственно, чтобы получить аналитическое выражение для меры однородности при конкретной функции потерь, необходимо аналитически найти оптимальное значение константы и подставить его в формулу для $H(X)$.
#
# Выведите аналитическое выражение для меры неоднородности для следующих функций потерь:
# 1. $L(y, c) = (y-c)^2$;
# 2. $L(y, c) = |y-c|$.
#
# Найдите также оптимальное предсказание в листьях дерева.

# %% [markdown]
# см. влож.

# %% [markdown]
# ### Задача 3

# %% [markdown]
# В случае задачи классификации рассматривается вероятностное предсказание, и мера неоднородности имеет вид
# $$H(X) = \min_{\substack{P \in [0, 1]^K \\ p_1+...+p_K=1}} \dfrac{1}{n} \sum_{i=1}^n L\left(Y_i, P\right).$$
# Выведите и упростите меру неоднородности, найдите оптимальные оценки вероятностей в листах для следующих функций потерь:
# * $L(y, P) = \sum\limits_{k=1}^K \left(p_k-I\{y=k\}\right)^2$;
# * $L(y, P) = -\sum\limits_{k=1}^K I\{ y=k\}\log p_k$.

# %% [markdown]
# см. влож.

# %% [markdown]
# ### Задача 4

# %% [markdown]
# Каждый студент DS-потока должен написать свое дерево. Что ж, время пришло...
#
# *Советы.*
# * Для отладки кода советуем строить простые деревья глубины 1-3 на простых датасетах по 10-20 объектах, печатать обучаемые параметры и т.д.. Если все хорошо работает, в финальном решении убирайте отладочный вывод.
# * Сравните качество реализованного дерева с качеством реализации из sklearn. Ровно такое же качество вы можете не получить из-за различных небольших оптимизаций, но если качество отличается на порядок, стоит проверить свою реализацию.
# * Сначала лучше разобраться с одной задачей (регрессией или классификацией), а затем переходить к другой.
#
# Ноутбук состоит из нескольких частей. Для удобства тут можно отмечать прогресс:
#
# - [x] Реализованы меры неоднородности
# - [x] Реализован `_build` в `BaseDecisionTree`
# - [x] Реализован `predict_instance` для `DecisionTreeRegressor`
# - [x] Реализован `predict_proba_instance` для `DecisionTreeClassifier`
# - [ ] Протестировано дерево на задаче регрессии для датасета `boston`
# - [ ] Задача классификации на датасете с пропусками

# %% [markdown]
# Вспомним, как именно происходит построение решающего дерева. Для построения дерева в каждой нелистовой вершине происходит разбиение подвыборки на две части по некоторому признаку $x_j$. Этот признак и порог $t$, по которому будет происходить разбиение, мы хотим брать не произвольно, а основываясь на соображениях оптимальности.  Для этого нам необходимо знать некоторый фукционал качества, который будем оптимизировать при построении разбиения.
#
# Обозначим через $X_m$ — множество объектов, попавших в вершину $m$, разбиваемую на данном шаге, а через $X_\ell$ и $X_r$ — объекты, попадающие в левое и правое поддерево соответственно при заданном правиле $I\{x_j < t\}$. Пусть также $H$ — используемая мера неоднородности (impurity).
#
# Выпишите функционал, который необходимо минимизировать при разбиении вершины:

# %% [markdown]
# **Ответ:** $H(X)=\frac{1}{n}\sum_{i=1}^n (Y_i-\bar Y)^2$ - в задаче регрессии (см п. 2). Или по абсолютной функции потерь
#
# ${H(X)=1-\sum_{k=1}^K\hat p_k^2 }$ - в задаче классификации (см. п. 3), где
# $\hat p_k=\frac{1}{n}\sum_{i=1}^n \mathbf 1\{Y_i=k\}$. Или по энтропии

# %% [markdown]
# **Реализация мер неоднородности.**

# %% [markdown]
# Вспомните еще раз, на какой общей идее основаны меры неоднородности и какую характеристику выборки они стремятся оптимизировать?
#
# **Ответ:** Мера неоднородности оценивает величину разброса таргета в вершине.
# Хорошее разбиение: после него больше уверены в ответе в вершине.
# Т.е. хотим разбить вершину на две так, чтобы полученные две вершины
# были более однородны по таргетам.

# %% [markdown]
# Перед тем, как непосредственно работать с решающими деревьями, реализуйте функции подсчёта значения мер неоднородности вершин решающих деревьев. Использовать готовые реализации мер или классов для решающих деревьев из `sklearn` и из других библиотек **запрещено.** Также при реализации мер неоднородности по причине неэффективности **запрещается использовать циклы**. Воспользуйтесь библиотекой `numpy`.
#
# Каждая функция принимает на вход одномерный `numpy` — массив размерности `(n,)` из значений отклика.

# %%
# Код функций, реализующих меры неоднородности для разбиения.

def mean_square_impurity(y: np.ndarray):
    ''' Мера по квадратичной функции потерь. '''
    y = np.array(y)
    if y.size == 0:
        return 0.0
    return np.mean(np.power(y - np.mean(y), 2))


def mean_abs_impurity(y: np.ndarray):
    ''' Мера по абсолютной функции потерь. '''
    y = np.array(y)
    if y.size == 0:
        return 0.0
    return np.mean(np.abs(y - np.quantile(y, 0.5)))


def get_probs_by_y(y: np.ndarray):
    ''' Возвращает вектор частот для каждого класса выборки. '''
    classes, counts = np.unique(y, return_counts=True)
    return counts / np.sum(counts)


def gini_impurity(y: np.ndarray):
    ''' Индекс Джини. '''
    y = np.array(y)
    if y.size == 0:
        return 0.0
    p = get_probs_by_y(y)
    return 1 - np.sum(p ** 2)


def entropy_impurity(y: np.ndarray):
    ''' Энтропия.'''
    y = np.array(y)
    if y.size == 0:
        return 0.0
    p = get_probs_by_y(y)
    mask = p > 0
    return -np.sum(p[mask] * np.log2(p[mask]))

# %% [markdown]
# Протестируйте реализованные функции.
#
# Тесты для распределения вероятностей на классах.

# %%
assert np.allclose(get_probs_by_y([1, 1, 2, 2, 7]), np.array([0.4, 0.4, 0.2]))
assert np.allclose(get_probs_by_y([1]), np.array([1]))

# %% [markdown]
# Тесты для реализации мер.

# %%
# Для однородных данных мера должна быть 0
assert np.allclose(entropy_impurity([25]), 0)
assert np.allclose(gini_impurity([25]), 0)
assert np.allclose(mean_square_impurity([10, 10, 10]), 0)
assert np.allclose(mean_abs_impurity([10, 10, 10]), 0)

# Для равномерного распределения
assert np.allclose(gini_impurity([0, 1]), 0.5)
assert np.allclose(entropy_impurity([0, 1]), 1.0)

# %% [markdown]
# **Реализация класса решающего дерева.**
#
# Для того, чтобы лучше понять, как устроены решающие деревья и как именно устроен процесс их построения, вам предлагается реализовать класс `BaseDecisionTree`, реализующий базовые функции решающего дерева.  Большая часть кода уже написана.
#
# Используются следующие классы:
#
# **Класс** `BaseDecisionTree` — класс для решающего дерева, в котором реализовано построение дерева. Все вершины дерева хранятся в списке `self.nodes`, при этом вершина с номером 0 — корень.
#
#
# * `__init__` — инициализация дерева. Здесь сохраняются гиперпараметры дерева: `impurity`, `max_depth`, `min_samples_split` и инициализируется список вершин, состоящий только из одной вершины — корневой,
# * `build_` — рекурсивная функция построения дерева. В ней при посещении каждой вершины дерева проверяются условия, стоит ли продолжать разбивать эту вершину. Если да, то перебираются все возможные признаки и пороговые значения и выбирается та пара (признак, значение), которой соответствует наименьшее значение меры неоднородности дерева,
# * `fit` — функция обучения дерева, принимающая на вход обучающую выборку. В этой функции происходит предподсчёт всех возможных пороговых значений для каждого из признаков, а затем вызывается функция `build_`.
#
# **Класс** `Node` — класс вершины дерева. Внутри вершины, помимо разделяющего признака и порога, хранятся `self.left_child`, `self.right_child` — номера дочерних вершин, а также `self.left_prob` и `self.right_prob` — вероятности попадания элемента в каждую из них. При этом в листовых вершиных хранятся также `self.y_values` — значения соответствующих элементов выборки, попавших в вершину.
#
# * `__init__` — инициализация вершины. Принимает в качестве аргументов разделяющий признак и пороговое значение и сохраняет их.
#
# **Класс** `DecisionTreeRegressor` — наследник класса `BaseDecisionTree`, в котором реализованы функции для предсказаний при решении задачи регрессии.
#
# * `predict_instance` — получение предсказания для одного элемента выборки. Выполняется посредством спуска по решающему дереву до листовой вершины,
#
# * `predict` — получение предсказаний для всех элементов выборки.
#
#
# **Класс** `DecisionTreeClassifier` — наследник класса `BaseDecisionTree`, в котором реализованы функции для предсказаний при решении задачи классификации.
# * `predict_proba_instance` — предсказание распределения вероятностей по классам для одного элемента выборки,
# * `predict_proba` — предсказание распределения вероятностей по классам для всех элементов выборки,
# * `predict` — предсказание меток классов для всех элементов выборки.

# %% [markdown]
# Перед написанием кода разбиения дерева, для каждого непрерывного признака предложите стратегию выбора кандидатов на порог разбиения. Почему рассматривать другие значения в качестве пороговых не имеет смысла?

# %% [markdown]
# **Ответ:** Можно смотреть только по множесту значений этого признака, а точнее по любым точкам между каждыми двумя признаками. При выборе любых других точек найдется соотвествующее аналогичное разбиение по предложенному ранее методу. Любое значение меньше чем минимальное или больше чем максимальное так же бесполезно, потому что оно тривиально: после него вся выборка отправится в одну вершину: дерево не произвело разделения

# %% [markdown]
# **Структура решающего дерева**
#
#
# ![fBDwbb5VHNQ.jpg](data:image/jpeg;base64,...)

# %%
def get_not_nans(arr: np.ndarray):
    '''
    Функция, которая создаёт и возвращает новый массив
    из всех элементов переданного массива, не являющихся Nan.
    '''

    return arr.copy()[~np.isnan(arr)]


class Node(object):
    def __init__(self, split_feature: Optional[int]=None, split_threshold: Optional[float]=None):
        '''
        Функция инициализации вершины решающего дерева.

        Параметры.
        1) split_feature — номер разделяющего признака
        2) split_threshold — пороговое значение
        '''

        self.split_feature = split_feature
        self.split_threshold = split_threshold

        # По умолчанию считаем, что у вершины нет дочерних вершин.
        self.left_child, self.right_child = None, None

        # Вероятности попадания в каждую из дочерних вершин нужно поддерживать
        # для корректной обработки данных с пропусками
        self.left_prob, self.right_prob = 0, 0

        # Массив значений y. Определён только для листовых вершин дерева
        self.y_values = None


class BaseDecisionTree(BaseEstimator):
    '''
    Здесь содержится реализация всех основных функций для работы
    с решающим деревом.

    Наследование от класса BaseEstimator нужно для того, чтобы
    в дальнейшем данный   класс можно было использовать в
    различных функциях библиотеки sklearn, например, в функциях
    для кросс-валидации.
    '''

    def __init__(
        self,
        impurity: Callable[[np.ndarray], float],
        max_depth: Optional[int]=None, min_samples_split: int=2
    ):
        '''
        Функция инициализации решающего дерева.

        Параметры.
        1) impurity — мера неоднородности,
        2) max_depth — максимальная глубина дерева,
        3) min_samples_split — минимальное количество элементов
        обучающей выборки,  которое должно попасть в вершину,
        чтобы потом происходило разбиение этой вершины.
        '''

        self.impurity = impurity
        self.max_depth = max_depth
        self.min_samples_split = min_samples_split

        # Список всех вершин дерева. В самом начале
        # работы алгоритма есть только одна
        # вершина — корень.
        self.nodes = [Node()]

        # Количество классов. Актуально только
        # при решении задачи классификации.
        self.class_count = 1

        # Сюда нужно будет записать все значения
        # для каждого из признаков датасета
        # (они будут нашими порогами).
        self.feature_values = None

    def build_(self, node_index: int, X: np.ndarray, y: np.ndarray, node_depth: int = 0):
        '''
        Рекурсивная функция построения решающего дерева.

        Параметры.
        1) node_index — номер рассматриваемой вершины
        2) X, y — обучающая выборка, попавшая в текущую вершину
        3) node_depth — глубина вершины с номером node_index
        '''

        if node_depth == 0:
            print(f"Начало построения дерева, {len(y)} образцов")

        stop_cond = [
            node_depth == self.max_depth, # достигли максимальной глубины
            len(y) < self.min_samples_split, # число элементов в листе мало
        ]

        if any(stop_cond):
            # Еcли строим дерево для классификации, то
            # сохраняем метки классов всех элементов выборки,
            # попавших в вершину.
            if callable(getattr(self, 'set_class_count', None)):
                self.nodes[node_index].y_values = y.copy()

            # Для регрессии сразу вычислим среднее всех
            # элементов вершины.
            else:
                self.nodes[node_index].y_values = np.mean(y)
            return

        best_impurity_value = np.inf
        best_feature, best_threshold = 0, 0
        sample_size, feature_count = X.shape
        found_valid_split = False

        # переберём все возможные признаки и значения порогов,
        # найдём оптимальный признак и значение порога
        # и запишем их в best_feature, best_threshold
        for feature_id in range(feature_count):
            thresholds = self.feature_values[feature_id]
            if thresholds.size == 0:
                # все значения NaN для этого признака — пропускаем
                continue
                
            for threshold in thresholds:
                not_nan_mask = ~np.isnan(X[:, feature_id])
                mask_left = not_nan_mask & (X[:, feature_id] <= threshold)
                mask_right = not_nan_mask & (X[:, feature_id] > threshold)

                y_left = y[mask_left]
                y_right = y[mask_right]

                if y_left.size == 0 or y_right.size == 0:
                    continue

                curr_impurity = (y_left.size / sample_size) * self.impurity(y_left) + \
                (y_right.size / sample_size) * self.impurity(y_right)

                if np.isnan(curr_impurity) or np.isinf(curr_impurity):
                    continue

                found_valid_split = True
                if curr_impurity < best_impurity_value:
                    best_impurity_value = curr_impurity
                    best_feature = feature_id
                    best_threshold = threshold
    
        if not found_valid_split or best_feature is None:
            self.nodes[node_index].y_values = y.copy()
            return

        # сохраним найденные параметры в класс текущей вершины
        self.nodes[node_index].split_feature = best_feature
        self.nodes[node_index].split_threshold = best_threshold
        
        # разделим выборку на 2 части по порогу
        not_nan_mask = ~np.isnan(X[:, best_feature])
        mask_left = not_nan_mask & (X[:, best_feature] <= best_threshold)
        mask_right = not_nan_mask & (X[:, best_feature] > best_threshold)

        X_left, y_left = X[mask_left], y[mask_left]
        X_right, y_right = X[mask_right], y[mask_right]

        denom = np.sum(not_nan_mask)
        if denom > 0:
            left_prob = np.sum(mask_left) / denom
            right_prob = np.sum(mask_right) / denom
        else:
            # если у всех записей признак NaN — распределим поровну
            left_prob, right_prob = 0.5, 0.5

        self.nodes[node_index].left_prob = float(left_prob)
        self.nodes[node_index].right_prob = float(right_prob)

        # создаём левую и правую дочерние вершины,
        # и кладём их в массив self.nodes
        self.nodes.append(Node())
        self.nodes.append(Node())

        # сохраняем индексы созданных вершин в качестве
        # левого и правого сына вершины node_index
        self.nodes[node_index].left_child, self.nodes[node_index].right_child =\
            len(self.nodes)-2, len(self.nodes)-1

        # рекурсивно строим дерево для дочерних вершин
        self.build_(self.nodes[node_index].left_child, X_left, y_left, node_depth+1)
        self.build_(self.nodes[node_index].right_child, X_right, y_right, node_depth+1)

    def fit(self, X: np.ndarray, y: np.ndarray):
        '''
        Функция, из которой запускается построение
        решающего дерева по обучающей выборке.

        Параметры.
        X, y — обучающая выборка
        '''
        
        # сохраним заранее все пороги для каждого из
        # признаков обучающей выборки
        X, y = np.array(X), np.array(y)
        self.feature_values = []
        for feature_id in range(X.shape[1]):
            self.feature_values.append(
                np.unique(get_not_nans(X[:, feature_id]))
            )

        set_class_count = getattr(self, 'set_class_count', None)

        # если строится дерево для классификации,
        # то нужно посчитать количество классов
        if callable(set_class_count):
            set_class_count(y)
        self.build_(0, X, y)
        # начинаем рекурсию с корня

# %% [markdown]
# Теперь, когда общий код решающего дерева написан, нужно сделать обёртки над `BaseDecisionTree` — классы `DecisionTreeRegressor` и `DecisionTreeClassifier` для использования решающего дерева в задачах регрессии и классификации соответственно.
#
# Допишите функции `predict_instance` и `predict_proba_instance` в классах для регрессии и классификации соответственно. В этих функциях нужно для одного элемента $x$ выборки промоделировать спуск в решающем дереве, а затем по листовой вершине, в которой окажется объект, посчитать для классификации — распределение вероятностей, а для регрессии — число $y$.

# %%
class DecisionTreeRegressor(BaseDecisionTree):
    def predict_instance(self, x: np.ndarray, node_index: int):
        '''
        Рекурсивная функция, предсказывающая значение
        y для одного элемента x из выборки.

        Параметры.
        1) x — элемент выборки, для которого
        требуется предсказать значение y
        2) node_index — рассматриваемая вершина дерева
        '''

        node = self.nodes[node_index]

        # если вершина — лист, возвращаем в качестве предсказания
        # среднее всех элементов, содержащихся в ней
        if node.left_child is None:
            yv = np.array(node.y_values)
            if yv.size == 0:
                return np.nan
            return float(np.mean(yv))

        # если у объекта x значение признака по
        # которому происходит разделение,  меньше
        # порогового, то спускаемся в левое поддерево,
        # иначе — в правое
        val = x[node.split_feature]
        if not np.isnan(val):
            if val <= node.split_threshold:
                return self.predict_instance(x, node.left_child)
            else:
                return self.predict_instance(x, node.right_child)


        # а если у элемента отсутствует значение
        # разделяющего признака,  то будем спускаться
        # в оба поддерева
        else:
            left_predict = self.predict_instance(x, node.left_child)
            right_predict = self.predict_instance(x, node.right_child)
            return node.left_prob * left_predict + node.right_prob * right_predict

    def predict(self, X: np.ndarray):
        '''
        Функция, предсказывающая значение
        y для всех элементов выборки X.

        Параметры.
        X — выборка, для которой требуется
        получить вектор предсказаний y
        '''
        X = np.array(X)
        return [self.predict_instance(x, 0) for x in X]

# %% [markdown]
# Для удобства реализации функции `predict_proba_instance` класса `DecisionTreeClassifier` будем считать, что все классы имеют целочисленные метки от 0 до $k-1$, где $k$ — количество классов. Если бы это условие не было выполнено, то нужно было бы сначала сделать предобработку меток классов в датасете.

# %%
x = np.array([0, 2, 0])
np.array(x[np.array([1, 2])])
# Out:
# array([2, 0])

# %%
class DecisionTreeClassifier(BaseDecisionTree):
    def set_class_count(self, y: np.ndarray):
        '''
        Функция, вычисляющая количество классов
        в обучающей выборке.

        Параметры.
        y — значения класса в обучающей выборке
        '''

        self.class_count = np.max(y) + 1

    def predict_proba_instance(self, x: np.ndarray, node_index: int):
        '''
        Рекурсивная функция, предсказывающая вектор
        вероятностей принадлежности  объекта x
        к классам

        Параметры.
        1) x — элемент выборки, для которого
        требуется предсказать значение y
        2) node_index — вершина дерева, в которой
        находится алгоритм
        '''

        node = self.nodes[node_index]

        if node.left_child is None:
            # считаем долю каждого класса и возвращаем вектор вероятностей
            probs = np.zeros(self.class_count, dtype=float)
            classes, counts = np.unique(node.y_values, return_counts=True)
            probs[classes] = counts / np.sum(counts)
            return probs

        # если у объекта x значение признака по которому
        # происходит разделение, меньше порогового,
        # то спускаемся в левое поддерево, иначе — в правое
        if x[node.split_feature] <= node.split_threshold:
            return self.predict_proba_instance(x, node.left_child)
        elif x[self.nodes[node_index].split_feature] > node.split_threshold:
            return self.predict_proba_instance(x, node.right_child)

        # а если у объекта отсутствует значение
        # разделяющего признака, то будем спускаться
        # в оба поддерева
        else:
            left_predict = self.predict_proba_instance(
                x, node.left_child)
            right_predict = self.predict_proba_instance(
                x, node.right_child)
            return node.left_prob * left_predict + node.right_prob * right_predict

    def predict_proba(self, X: np.ndarray):
        '''
        Функция, предсказывающая вектор вероятностей
        принадлежности объекта x к классам для
        каждого x из X

        Параметры.
        X — выборка, для которой требуется получить вектор предсказаний y
        '''

        X = np.array(X)

        return [self.predict_proba_instance(x, 0) for x in X]

    def predict(self, X: np.ndarray):
        '''
        Функция, предсказывающая метку класса для
        всех элементов выборки X.

        Параметры.
        X — выборка, для которой требуется получить
        вектор предсказаний y
        '''

        return np.argmax(self.predict_proba(X), axis=1)

# %% [markdown]
# **Подбор параметров.**
#
# В этой части задания вам предлагается поработать с написанным решающим деревом, применив его к задачи классификации и регрессии, и в обеих задачах подобрать оптимальные параметры для построения.
#
# Не забывайте писать выводы.

# %% [markdown]
# **1. Задача регрессии.**
#
# Теперь самое время протестировать работу написанного нами решающего дерева. В качестве датасета возьмите `energy` из семинара.

# %%
from ucimlrepo import fetch_ucirepo

energy = fetch_ucirepo(id=242)

energy_X = energy.data.features
energy_y = energy.data.targets

energy_y = energy_y["Y2"]  # берём только Y2 (Cooling Load)


def find_name(old_name: str):
    for _, row in energy.variables.iterrows():
        if row["name"] == old_name:
            return row.description


energy_X = energy_X.rename(columns=find_name)
energy_y.name = find_name(energy_y.name)

# %% [markdown]
# Сначала надо разбить выборку на train и test.

# %%
X_train, X_test, y_train, y_test = train_test_split(energy_X, energy_y, random_state=42)

# %% [markdown]
# Далее для метрики `r2_score` посмотрите значение при использовании различных мер неоднородности. Возьмите оптимальные значения `max_depth` и `min_samples_split` из семинара

# %%
X_train.head(5)
# Out:
#      Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 357                  0.76         661.5      416.5     122.50             7.0
# 73                   0.74         686.0      245.0     220.50             3.5
# 352                  0.79         637.0      343.0     147.00             7.0
# 497                  0.79         637.0      343.0     147.00             7.0
# 145                  0.98         514.5      294.0     110.25             7.0
#
#      Orientation  Glazing Area  Glazing Area Distribution
# 357            3          0.25                          2
# 73             3          0.10                          1
# 352            2          0.25                          2
# 497            3          0.25                          5
# 145            3          0.10                          3

# %%
regression_impurity = [mean_square_impurity, mean_abs_impurity]
impurity_names = [gini_impurity, entropy_impurity]
max_depth = 6
min_samples_split = 4

# %%
preds = []
for impurity_name in regression_impurity:
    model = DecisionTreeRegressor(impurity=impurity_name, max_depth=max_depth, min_samples_split=min_samples_split)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    preds.append(r2_score(y_test, y_pred))

print(f'R2_score для метрики mean_square_impurity: {preds[0]:.4f}')
print(f'R2_score для метрики mean_abs_impurity: {preds[1]:.4f}')
# Out:
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# R2_score для метрики mean_square_impurity: 0.9650
# R2_score для метрики mean_abs_impurity: 0.9485

# %% [markdown]
# Постройте графики зависимости `r2-score` от максимальной глубины дерева на обучающей и тестовой выборке для каждой меры на train и на test. В качестве максимальной глубины используйте значения от 1 до 14. Значение `min_samples_split` фиксируйте.
#
# *Совет.*
# Можете использовать функции с семинара

# %%
depths_grid = np.arange(1, 15)
preds = []
for depth in depths_grid:
    model = DecisionTreeRegressor(impurity=mean_square_impurity, max_depth=depth)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    preds.append(r2_score(y_test, y_pred))

plt.figure(figsize=(8, 6))
plt.scatter(depths_grid, preds)
plt.show()
# Out:
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов

# %% [markdown]
# Аналогично постройте график зависимости от минимального числа элементов в листе

# %%
depths_grid = np.arange(1, 15)
preds = []
for depth in depths_grid:
    model = DecisionTreeRegressor(impurity=mean_square_impurity, min_samples_split=depth, max_depth=7)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    preds.append(r2_score(y_test, y_pred))

plt.figure(figsize=(8, 6))
plt.scatter(depths_grid, preds)
plt.show()
# Out:
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов
# Начало построения дерева, 576 образцов

# %% [markdown]
# Сделайте вывод, в котором объясните, почему графики получились такими.
#
# Скорее всего, вы заметили, что дерево в этих экспериментах строится довольно медленно. Как можно ускорить его построение? Можно ли ускорить нахождение оптимального разбиения по некоторому вещественному признаку?

# %% [markdown]
# **Вывод.**
#
# С ростом глубины метрика выходит на константу при фиксированных остальных параметрах. Это связано с тем, что признаков ограниченное количество, и при некоторой конечной глубине дерево останавливается по другим критериям остановки, а значит и при большей глубиине оно будет останваливаться там же.
#
# Min_samples_split - это число, что если число признаков в листе меньше, чем оно, то дерево останвливается, поэтому при слишком больших значених дерево вершины достаточно быстро становились листовыми, не оптимально, и усредняли большее количество значений
#
# Можно изначально отсортировать значения признака, и затем при перехое к следующему элементу не вычислять всё с нуля, а вычитать учитывать только ушедший за шаг и пришедший за шаг элемент, оперируя константными арифмическими действиями

# %% [markdown]
# **2. Задача классификации, работа с пропусками**

# %% [markdown]
# В этом пункте вам предстоит освоиться с обработкой пропусков в решающих деревьях, реализованной ранее.

# %% [markdown]
# Рассмотрим датасет, в котором часть данных пропущена. В качестве примера возьмём <a href="https://www.openml.org/search?type=data&status=active&id=40536">датасет</a> для определения подходят ли люди друг другу по таким признакам как возраст, хобби, оценке важности некоторых свойств партнёра и другим

# %% [markdown]
# Поскольку предсказание в дереве на данных с пропусками часто занимает сильно больше времени, чем в случае отсутствия пропусков (так как часто приходится спускаться разу в 2 поддерева), то для экономии времени сократим датасет, взяв из него только первые 10000 строк данных.

# %%
import arff

with open("speeddating.arff", "r") as f:
    arff_data = arff.load(f)

columns = [attr[0] for attr in arff_data["attributes"]]
df = pd.DataFrame(arff_data["data"], columns=columns)
df.to_csv("speeddating.csv", index=False)

# %%
dating_df = pd.read_csv("speeddating.csv")[:10000]
target = dating_df["match"]
dating_df = dating_df.drop(
    ["has_null", "match", "decision", "decision_o", "met"], axis=1
)
dating_df.head()
# Out:
#    wave  gender   age  age_o  d_age d_d_age  \
# 0   1.0  female  21.0   27.0    6.0   [4-6]
# 1   1.0  female  21.0   22.0    1.0   [0-1]
# 2   1.0  female  21.0   22.0    1.0   [0-1]
# 3   1.0  female  21.0   23.0    2.0   [2-3]
# 4   1.0  female  21.0   24.0    3.0   [2-3]
#
#                                     race  \
# 0  Asian/Pacific Islander/Asian-American
# 1  Asian/Pacific Islander/Asian-American
# 2  Asian/Pacific Islander/Asian-American
# 3  Asian/Pacific Islander/Asian-American
# 4  Asian/Pacific Islander/Asian-American
#
#                                   race_o  samerace  importance_same_race  ...  \
# 0            European/Caucasian-American         0                   2.0  ...
# 1            European/Caucasian-American         0                   2.0  ...
# 2  Asian/Pacific Islander/Asian-American         1                   2.0  ...
# 3            European/Caucasian-American         0                   2.0  ...
# ...

# %% [markdown]
# Предобработаем датасет, заменив категориальные признаки one-hot векторами.

# %%
dating_df = pd.get_dummies(dating_df, drop_first=True, dtype=int)
dating_df.head()
# Out:
#    wave   age  age_o  d_age  samerace  importance_same_race  \
# 0   1.0  21.0   27.0    6.0         0                   2.0
# 1   1.0  21.0   22.0    1.0         0                   2.0
# 2   1.0  21.0   22.0    1.0         1                   2.0
# 3   1.0  21.0   23.0    2.0         0                   2.0
# 4   1.0  21.0   24.0    3.0         0                   2.0
#
#    importance_same_religion  pref_o_attractive  pref_o_sincere  \
# 0                       4.0               35.0            20.0
# 1                       4.0               60.0             0.0
# 2                       4.0               19.0            18.0
# 3                       4.0               30.0             5.0
# 4                       4.0               30.0            10.0
#
#    pref_o_intelligence  ...  d_expected_happy_with_sd_people_[5-6]  \
# 0                 20.0  ...                                      0
# 1                  0.0  ...                                      0
# ...

# %% [markdown]
# Посмотрим на распределение пропущенных значений по признакам.

# %%
np.sum(dating_df.isnull(), axis=0)
# Out:
# wave                               0
# age                               95
# age_o                            104
# d_age                              0
# samerace                           0
#                                 ...
# d_expected_num_matches_[5-18]      0
# d_like_[6-8]                       0
# d_like_[9-10]                      0
# d_guess_prob_liked_[5-6]           0
# d_guess_prob_liked_[7-10]          0
# Length: 437, dtype: int64

# %% [markdown]
# Разобьём данные на обучающую и тестовую выборки в отношении 3:1.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    dating_df.values, target.values, random_state=777
)

# %% [markdown]
# Посчитайте `accuracy` для каждой из мер неоднородности для разбиения деревьев для классификации при фиксации `max_depth`$ = 5$ `min_samples_split`$ = 3$.

# %%
preds = []
for impurity in impurity_names:
    model = DecisionTreeClassifier(impurity=impurity, max_depth=5, min_samples_split=3)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    preds.append(accuracy_score(y_test, y_pred))

print(f'Accuracy_score для метрики gini_impurity: {preds[0]:.4f}')
print(f'Accuracy_score для метрики entropy_impurity: {preds[1]:.4f}')
# Out:
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Accuracy_score для метрики gini_impurity: 0.8258
# Accuracy_score для метрики entropy_impurity: 0.8325

# %% [markdown]
# Постройте графики зависимости `accuracy` от максимальной глубины дерева и минимального числа элементов в листе на обучающей и тестовой выборке, аналогично тому как сделали в пунтке с регресиией для `r2-score`.

# %%
depths_grid = np.arange(1, 15)
preds = []
for depth in depths_grid:
    model = DecisionTreeClassifier(impurity=mean_square_impurity, min_samples_split=3, max_depth=depth)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    preds.append(accuracy_score(y_test, y_pred))

plt.figure(figsize=(8, 6))
plt.scatter(depths_grid, preds)
plt.show()
# Out:
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов

# %% [markdown]
# Сделайте выводы. Почему графики получились такими? Как соотносятся оптимальные значения параметров на обучающей и на тестовой выборках?

# %%
depths_grid = np.arange(1, 15)
preds = []
for depth in depths_grid:
    model = DecisionTreeClassifier(impurity=mean_square_impurity, min_samples_split=depth, max_depth=7)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    preds.append(accuracy_score(y_test, y_pred))

plt.figure(figsize=(8, 6))
plt.scatter(depths_grid, preds)
plt.show()
# Out:
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов
# Начало построения дерева, 6283 образцов

# %% [markdown]
# **Вывод.**
#
# В глубине модель переобучается и плохо предсказывает на тестовых данных. В min_samples_split достаточно неочевидная зависимость, но видим, что в некоторой области она выходит на константу, одно из этих значений лучше взять

# %% [markdown]
# ### Задача 5

# %% [markdown]
# Онлайн-магазин хочет улучшить клиентский опыт и сократить число жалоб на задержки доставки. Вы аналитик этого магазина, вас для этого необходимо научиться предсказывать время доставки заказа до клиента в днях. Такая модель поможет заранее информировать покупателей о сроках и оптимизировать логистику, учитывая расстояние, нагрузку на склад, трафик и погодные условия.
#
# **Ваша задача:** по данным предсказать время доставки заказа до клиента в днях (`delivery_time_days`).
#
# В соревновании вам предоставлены:
# * `train.csv` — данные о заказах
# * `test.csv` — новые данные о заказах (без таргета)
# * `sample_submission.csv` — шаблон для ваших предсказаний
#
#
# **Основная метрика**: MAE
#
#
# **Некоторые советы:**
# - Подумайте, какие гиперпараметры есть у решающего дерева и как их подбирать.
#
# Описание данных:
# | Признак         | Тип             | Описание                                                                 |
# | ----------------| --------------- | ------------------------------------------------------------------------ |
# | `distance_km`     | вещественный    | Расстояние до клиента в километрах                              |
# | `order_size`      | целочисленный   | Количество товаров в заказе                                       |
# | `weight_kg`       | вещественный    | Суммарный вес заказа в килограммах                            |
# | `warehouse_load`  | вещественный    | Текущая загрузка склада (0–1, где 1 — склад полностью загружен)          |
# | `traffic_index`   | целочисленный    | Индекс трафика/пробок                |
# | `weather_score`   | вещественный    | Оценка погодных условий (0–1, чем выше — тем лучше погода)                |
# | `delivery_time_days` | целевая       | Фактическое время доставки заказа в днях                                 |
#
#
# Ссылка: https://www.kaggle.com/competitions/ds-3-2025-ml-2/
#
# Инвайт: https://www.kaggle.com/t/64c2570ec27c48a9b6e3999cc0559326

# %% [markdown]
# **Правила**
#
# * В Kaggle в данное тренировочное соревнование можно отправлять не более 10 решений в день (11-ю система не позволит).
# * Решения индивидуальные.
# * До окончания соревнования доступны значения качества, посчитанные только на случайных 40% тестовых данных. Значения отображаются в Public Leaderboard.
# * После окончания соревнования становится доступным Private Leaderboard, в котором значения качества посчитаны на оставшихся 60% объектов.
# * Для включения в Private Leaderboard можно выбрать одну конкретную посылку.
# * В Leaderboard должны отображаться ваши **реальные имя и фамилия**. В противном случае решение может быть не зачтено.
# * Все файлы, которые вы отправляете в соревнование, видны организаторам соревнования. Файлы должны иметь понятное имя, при отправке файла в систему необходимо написать краткое описание решения. **Это может проверяться.**
# * В решении, отправляемом боту, должно быть отображено, результаты каких моделей вы отправляете в соревнование.
# * Не забывайте сделать пояснения к своему решению. **Решение может быть не зачтено, если в нем недостаточно пояснений**, даже если удалось попасть в топ-3.
# * Пользоваться можно любыми пройденными в наших курсах моделями.
# * Нельзя пользоваться любыми методами и моделями, которые мы не проходили, и которых не было в ранее в иных курсах, которые обязательны для всех.
# * Код решения выборочно может запускаться.
#
# **Советы**
#
# * Чтобы получить действительно хороший результат простого обучения моделей мало. Попробуйте подбор гиперпараметров, попробуйте ввести новые признаки для улучшения качества решения.
# * Некоторые инсайты по тому, какие признаки могут улучшить качество, можно получить если провести разведывательный анализ данных (EDA). Например, может иметь смысл изучить датасет на предмет наличия выбросов, исследовать пространственное распределение отклика.
# * Изучите различные методы, предложенные на занятиях.
# * Сохраняйте код и результаты каждой модели в отдельных файлах. Добавляйте к ним понятные описания, которые помогут вам при необходимости продолжить использовать решение.
#
# **Сдача задания**
#
# * **Дедлайн в Kaggle** совпадает с дедлайном по заданию. Дедлайн строгий, Kaggle не позволит сдать даже на секунду позже.
# * Также **до дедлайна необходимо сдать в бот** оформленное решение, соответствующее выбранной посылке. **Решение может быть не зачтено, если в нем недостаточно пояснений**, даже если удалось попасть в топ-3.
#
# **Баллы**
#
# TODO

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
df_train
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_train = pd.read_csv('train.csv')
#       2 df_test = pd.read_csv('test.csv')
#       3 df_train
#
# ...

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

y_train = df_train['delivery_time_days'].values

test_ids = df_test['id'].astype(int)

def make_features(df):
    df = df.copy()
    df['']
    df['dist_log'] = np.log1p(df['distance_km'])
    df['dist_x_traffic'] = df['distance_km'] * df['traffic_index']
    df['weight_dist'] = df['distance_km'] * df['weight_kg']
    drop_cols = ['delivery_time_days', 'order_size', 'weight_kg', 'warehouse_load', 'traffic_index']
    for c in drop_cols:
        if c in df.columns:
            df = df.drop(columns=c)
    return df

X_train = make_features(df_train)
X_test = make_features(df_test)

if 'id' in X_train.columns:
    X_train = X_train.drop(columns=['id'])
if 'id' in X_test.columns:
    X_test = X_test.drop(columns=['id'])

train_cols = list(X_train.columns)
test_cols = list(X_test.columns)

X_train_vals = X_train.values
X_test_vals = X_test.values

model = DecisionTreeRegressor(criterion='absolute_error', max_depth=5, random_state=42)
model.fit(X_train_vals, y_train)

y_pred = model.predict(X_test_vals)

submission = pd.DataFrame({
    'id': test_ids,
    'delivery_time_days': y_pred
})

submission.to_csv('submission.csv', index=False)
print("Saved submission.csv with", len(submission), "rows")
# Out:
# Saved submission.csv with 1000 rows

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('train.csv')
print(df.describe(include='all'))
sns.histplot(df['delivery_time_days'], bins=50, kde=True); plt.title('target dist'); plt.show()
sns.scatterplot(x='distance_km', y='delivery_time_days', data=df); plt.show()
sns.heatmap(df.corr(), annot=True, fmt='.2f'); plt.show()

# Check outliers in target
q1, q3 = df['delivery_time_days'].quantile([0.25,0.75])
iqr = q3 - q1
low, high = q1 - 1.5*iqr, q3 + 1.5*iqr
print('target bounds:', low, high)
# Out:
#                 id  distance_km   order_size    weight_kg  warehouse_load  \
# count  4000.000000  4000.000000  4000.000000  4000.000000     4000.000000
# mean   2507.711000   278.734788     4.986250    18.611353        0.492544
# std    1435.558218   260.197840     1.763332    23.715886        0.285621
# min       0.000000     0.015359     1.000000     0.100000        0.000053
# 25%    1275.750000   123.536063     4.000000    11.435829        0.246733
# 50%    2499.500000   256.645649     5.000000    15.153547        0.491267
# 75%    3757.250000   380.985003     6.000000    19.060578        0.733336
# max    4999.000000  2490.834790    11.000000   261.903519        0.999505
#
#        traffic_index  weather_score  delivery_time_days
# count    4000.000000    4000.000000         4000.000000
# mean        4.025250       0.497106           12.333209
# std         2.180207       0.219493            6.810371
# min         0.000000       0.000000            0.690961
# ...
