# %%
stack = []
bras = input()
opening = {'(', '[', '{'}
closing = {')', ']', '}'}
for bra in bras:
    if bra in opening:
        stack.append(bra)
    elif bra in closing:
        if len(stack) == 0:
            return 'no'
        else:
            if stack[-1]
# Out:
#   Cell In[19], line 6
#     if
#        ^
# SyntaxError: invalid syntax
